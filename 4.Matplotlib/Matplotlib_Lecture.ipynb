# %% [markdown]
# # Matplotlib
#
# - 데이터 시각화에 특화된 파이썬 라이브러리
# - 데이터 분석 결과를 쉽게 이해할 수 있도록 차트나 그래프로 표현 가능
# - 데이터를 시각화하면 데이터의 분포 및 데이터 간의 관계와 패턴 등을 한눈에 볼 수 있어 데이터의 특성을 쉽게 파악 가능

# %% [markdown]
# ## 그래프 그리기

# %% [markdown]
# ### 선 그래프
#
# - plot() 함수를 통해 선 그래프로 데이터를 시각화 가능
# - show() 함수를 통해 그려진 그래프를 화면에 출력
# - 선 그래프는 다음과 같이 리스트 또는 변수를 이용하여 그릴 수 있음

# %%
# 맷플롯립 중 그래프를 그리는 pyplot 모듈을 불러와 plt라는 벌명으로 사용

# %%
# 리스트 설정
# plot 함수 내에 x와 y의 범위를 직접 리스트 형태로 제시하여 그리기 가능

# %%
# 변수 설정
# numpy 라이브러리의 arange() 함수와 변수를 이용하여 x의 범위를 설정하고 y를 x와의 관계를 나타내는 식으로 작성한 후 그래프 그리기 가능

# %% [markdown]
# ### 산점도, 막대그래프
# - 산점도 : 두 변수 간의 관계를 점으로 시각화한 그래프
# - 막대그래프 : 데이터의 크기를 직사각형 막대의 길이로 표현하여 항목별 크기를 비교하는 데 사용

# %%
# x,y : 모두 수치형 데이터

# %%
# x : 수치형/범주형 데이터, y : 수치형 데이터

# %% [markdown]
# ### 이미지 표시, 파이 차트
# - 이미지 표시 : 2차원 배열을 이미지로 시각화
# - 파이 차트 : 전체에 대한 각 부분의 비율을 부채꼴로 나타내는 원형 그래프

# %%
# 이미지 표시(1에 가까울수록 밝고 0에 가까울수록 어두움)

# %%
# 파이 차트

# (영역별 비율, 영역별 레이블, 표시할 숫자 형식(소수점 아래 첫째 자리))

# %% [markdown]
# ### 히스토그램, 히트맵
# - 히스토그램  : 데이터의 분포를 막대 그래프로 보여주는 것
# - 히트맵 : 데이터의 값을 색상의 명암으로 표현하여 시각화하는 그래프

# %%
# 히스토그램

data = [3,4,5,5,5,6,7,8,3,
        2,7,7,7,8,10,10,9]
# bins는 계급 개수로 기본값은 10
# 계급개수란 히스토그램에서 데이터를 나누는 구간의 수를 의미

# %%
# 히트맵

# %% [markdown]
# ## 속성 설정

# %% [markdown]
# ### 마크 지정
# - 마크는 각 데이터를 표시한 지점을 말함.
# - 마커는 기본적으로 작은 동그라미 모양이지만 다른 모양(ppt 참조)으로 번경할 수 있음.

# %% [markdown]
# ### 그래프 색상
# - 그래프의 색상을 다양하게 설정 가능

# %% [markdown]
# ### 선 종류
# - 그래프의 선을 다양하게 설정 가능

# %% [markdown]
# ### 축 레이블
# - 그래프의 x축과 y축의 이름뿐만 아니라 글자 크기와 정렬할 위치도 함께 설정 가능

# %%
x = np.arange(1,5)
y = np.arange(2,6)

plt.plot(x,y)
# (레이블명, 글자 크기, 여백 크기)

# %% [markdown]
# ### 범례
# - 그래프에서 데이터가 나타내는 것을 표시하는 영역

# %%
x = np.arange(1,5)
y = x ** 2

# 범례명을 지정 가능

# 범례의 위치를 설정 가능(오른쪽 위)

# %% [markdown]
# ### 축 범위
# - x축과 y축이 표시되는 범위를 xlim()과 ylim() 또는 axis()를 사용하여 임의로 설정 가능

# %%
# xlim()과 ylim() 사용


# x축 표시 범위

# y축 표시 범위

# %%
# axis() 활용

# x축, y축 범위를 차례대로 설정

# %% [markdown]
# ### 한 그래프에 여거 개의 선 그리기
# - x축과 y축을 서로 공유하는 여러 개의 선을 그릴 때는 plt.show()로 나타내기 전 그리려는 그래프의 함수를 여러 번 사용

# %%
# 세 개 그래프 속성 설정
