# %% [markdown]
# # Matplotlib 문제

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl 
mpl.rc('font',family='Malgun Gothic')   # 한글폰트 설정 "맑은 고딕"

# %% [markdown]
# ### 1. numpy 함수를 사용하여 다음 x,y 범위의 선 그래프를 출력하시오.
# - x : [1,3,5,7,9]
# - y : [1,2,3,4,5]

# %% [markdown]
# ### 2. 다음 주어진 식의 그래프를 그리시오. (주어진 x 범위는 numpy 함수를 활용하시오.)
#
# - x : [1,2,3,4,5]
# - y : x^2 + 2x + 1

# %% [markdown]
# ### 3. 다음 주어진 x,y 범위를 numpy로 생성 후 이에 대한 산점도를 그리시오.
# - x : [3,6,9,12,15]
# - y : [10,12,14,16,18]

# %% [markdown]
# ### 4. 다음 표를 참고하여 막대그래프를 그리시오.
#
#
# | x (과일) | y (판매량) |
# | :--- | :--- |
# | 사과 | 100 |
# | 바나나 | 80 |
# | 오렌지 | 120 |
# | 포도 | 95 |
# | 딸기 | 110 |

# %% [markdown]
# ### 5. 다음 표는 사람들이 좋아하는 아이스크림 맛을 비율로 나타낸 표이다. 이를 참고하여 파이 차트로 그리시오.
#
# | **ratio** (비율) | **label** (항목) |
# | :--- | :--- |
# | 40 | 초코 |
# | 30 | 바닐라 |
# | 20 | 딸기 |
# | 10 | 민트초코 |

# %% [markdown]
# ### 6. 다음 표는 한 학급 학생들의 코딩 테스트 점수를 정리한 것이다. 구간을 5개로 하여 히스토그램을 그리시오.(이 때 제목과 축 레이블을 설정하시오.)
# - 코딩 테스트 점수 : [85, 92, 78, 88, 75, 95, 80, 85, 90, 78, 82, 85]

# %% [markdown]
# ### 7. 다음 표는 각 지역의 월평균 기온 데이터이다. 이를 히트맵으로 그리시오.(이 때, 그래프를 참고하여 축 레이블을 설정하시오.)
#
#
# | **지역 / 계절** | 봄 | 여름 | 가을 | 겨울 |
# | :--- | :--- | :--- | :--- | :--- |
# | **지역A** | 10 | 25 | 15 | 5 |
# | **지역B** | 12 | 28 | 18 | 8 |
# | **지역C** | 8 | 22 | 12 | 3 |

# %% [markdown]
# ### 8. 다음 표는 월별로 각 게임의 사용자 수를 정리한 표이다. 이를 참고하여 다중 선 그래프를 그리시오.</br>(이 때 선끼리 색깔과 마커를 달리하여 구분되게 만들어야하며 적절한 제목, 축 레이블 그리고 범례를 표기해야함.)
#
# | 월 | 게임 A | 게임 B | 게임 C |
# |:---:|:---:|:---:|:---:|
# | 1월 | 100 | 80 | 130 |
# | 2월 | 120 | 100 | 125 |
# | 3월 | 150 | 95 | 115 |
# | 4월 | 140 | 110 | 100 |
# | 5월 | 160 | 130 | 90 |

# %% [markdown]
# ### 9. 타이타닉 데이터를 들고와 다음 문제들을 푸시오.</br>

# %%
from google.colab import files
uploaded = files.upload()

# %%
# 타이타닉 데이터 불러오기
titanicData = pd.read_csv('titanic_data.csv')
titanicData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 9-1. 성별에 따른 타이타닉호 생존자 수를 적절한 그래프를 활용하여 그리시오.</br>(Survived 칼럼에서 '1'이 생존, '0'이 사망임)

# %% [markdown]
# ### 9-2. 생존한 승객들의 객실 등급 비율을 파이 차트를 활용하여 그리시오.(소수점 아래 한자리 수까지 표시하기)

# %% [markdown]
# ### 9-3. 승객 나이에 따른 요금 관계를 산점도로 그리시오.</br>(단, dropna() 함수를 인터넷에서 찾아본 후 이를 적용해 null값이 있는 데이터를 제거하시오.)
